# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
plt.figure(figsize=(4,6))

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
hue='species'

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.cluster import kMeans
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-2224089165> in <cell line: 0>()
# ----> 1 from sklearn.cluster import kMeans
#
# ImportError: cannot import name 'kMeans' from 'sklearn.cluster' (/usr/local/lib/python3.11/dist-packages/sklearn/cluster/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install scikit-learn

# %%
from sklearn.cluster import kMeans
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-2224089165> in <cell line: 0>()
# ----> 1 from sklearn.cluster import kMeans
#
# ImportError: cannot import name 'kMeans' from 'sklearn.cluster' (/usr/local/lib/python3.11/dist-packages/sklearn/cluster/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from sklearn.cluster import KMeans
k_range=range(1,10)

# %%
wcss=[]

# %%
for k in k_range:
  km=kMeans(n_clusters=k)
  km.fit(df[['sepal_length','petal_length']])
  wcss.append(km.interia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3501073700> in <cell line: 0>()
#       1 for k in k_range:
# ----> 2   km=kmeans(n_clusters=k)
#       3   km.fit(df[['sepal_length','petal_length']])
#       4   wcss.append(km.interia)
#
# NameError: name 'kmeans' is not defined

# %%
import sklearn.cluster as cluster

# %%
from sklearn.cluster import KMeans
k_range=range(1,10)

# %%
wcss=[]

# %%
from sklearn.cluster import KMeans
wcss = []
k_range = range(1, 15)
for k in k_range:
    km = KMeans(n_clusters=k)
    km.fit(df[['sepal_length', 'petal_length']])
    wcss.append(km.inertia_)

# %%
plt.plot(k_range,wcss)
plt.title("elbow method")
plt.xlabel("k")
plt.ylabel("wcss")
# Out:
# Text(0, 0.5, 'wcss')

# %%
Kmeans=cluster.KMeans(n_clusters=5)

# %%
Kmeans=Kmeans.fit(df[['sepal_length', 'petal_length']])

# %%
Kmeans.cluster_centers_
# Out:
# array([[6.24594595, 4.77027027],
#        [5.006     , 1.464     ],
#        [5.53214286, 3.96071429],
#        [6.54347826, 5.54782609],
#        [7.475     , 6.3       ]])

# %%
df['clusters']=Kmeans.labels_

# %%
df['clusters']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    0
# 147    3
# 148    3
# 149    0
# Name: clusters, Length: 150, dtype: int32

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  clusters
# 0             5.1          3.5           1.4          0.2     setosa         1
# 1             4.9          3.0           1.4          0.2     setosa         1
# 2             4.7          3.2           1.3          0.2     setosa         1
# 3             4.6          3.1           1.5          0.2     setosa         1
# 4             5.0          3.6           1.4          0.2     setosa         1
# ..            ...          ...           ...          ...        ...       ...
# 145           6.7          3.0           5.2          2.3  virginica         3
# 146           6.3          2.5           5.0          1.9  virginica         0
# 147           6.5          3.0           5.2          2.0  virginica         3
# 148           6.2          3.4           5.4          2.3  virginica         3
# 149           5.9          3.0           5.1          1.8  virginica         0
#
# [150 rows x 6 columns]

# %%
df['clusters'].value_counts()
# Out:
# clusters
# 1    50
# 0    37
# 2    28
# 3    23
# 4    12
# Name: count, dtype: int64

# %%
scatterplot=sns.scatterplot(x='sepal_length',y='petal_length',hue='clusters',data=df)
